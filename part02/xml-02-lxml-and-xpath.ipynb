# %% [markdown]
# :::{error} Blank notebook
# This notebook is a placeholder for the XPATH lesson.
#
# In contrast to previous BS4 examples, this provides more granular filter with paths. For example, "Now I need only titleInfo/title, not relatedItem/titleInfo/title" → the path problem BS4 can't express → enter **lxml/XPath**
# :::
